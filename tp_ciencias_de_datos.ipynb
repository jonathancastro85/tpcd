# %% [markdown]
# <a href="https://colab.research.google.com/github/jonathancastro85/tpcd/blob/main/tp_ciencias_de_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## A - Comprensión del negocio (Business Understanding - CRISP-DM)

# %% [markdown]
# ### **Contexto del problema**
#
# Sector gastronomico, industria de restaurantes y comidas
#
# **Por que es relevante:** En la industria gastronomica, los margenes de ganacia suelen ser ajustados. Una gestion ineficiente del stock o desconocimiento de los productos que sostienen el negocio, pueden llevar a problemas financieros a futuro. Analizar estos datos permite ayudar en la toma de decisiones basado en evidencia
#
# **Quienes se benefician:** El dueño o gerente del restaurante, para maximizar la rentabilidad general
# ***El encargado del inventario***, para optimizar los pedidos a proveedores para evitar sobrestock o falta de stock
# **Clientes**, para disfrutar de lo que quieran sin que haya problemas de stock
#
# ###**Analizar las ventas de un local gastronómico**
#
# Identificar patrones de consumo, métodos de pago y posibles inconsistencias en los datos.
#
# ###**Objetivos**
#
# Analizar evolución de ventas.
#
# Identificar los métodos de pago más utilizados.
#
# Detectar problemas en los datos (fechas mal formateadas, tipos de pago inconsistentes).
#
# Preparar los datos para futuros análisis (limpieza y transformación).
#
# Identificar productos mas utilizados.
#
# Identificar ordenes(menues) mas populares
#
# ###**Preguntas a resolver**
#
# ¿Qué días y horarios se vende más?
#
# ¿Qué método de pago es más popular?
#
# ¿Hay errores en las fechas o registros duplicados?
#
# ¿Cómo afectan los datos sucios al análisis?
#
# Ordenes mas populares(menues)
#
# ###**Problemas detectados**
#
# Fechas en distintos formatos (ej: dd/mm/yyyy , mm-dd-yyyy , etc.).
#
# Tipos de pago inconsistentes (ej: "Cash", "cash", "CASH")
#
# Posibles valores nulos o vacíos
# Datos duplicados

# %%
# !mkdir tpcd
# !mkdir -p tpcd/data/interim/plots
# !mkdir tpcd/data/processed
# !mkdir tpcd/data/raw
# Out:
# mkdir: cannot create directory ‘tpcd’: File exists
# mkdir: cannot create directory ‘tpcd/data/processed’: File exists
# mkdir: cannot create directory ‘tpcd/data/raw’: File exists

# %%
# !git config --global user.name "jonathancastro85"
# !git config --global user.email "elchafas@gmail.com"

# %%
token = userdata.get('github')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_10144/4230827908.py in <cell line: 0>()
# ----> 1 token = userdata.get('github')
#
# NameError: name 'userdata' is not defined

# %%
# !git init
# !git remote set-url origin https://{token}@github.com/jonathancastro85/tpcd.git

# %%
# !git push -u origin master:main

# %%
# !git clone https://github.com/jonathancastro85/tpcd.git
# Out:
# Cloning into 'tpcd'...
# remote: Enumerating objects: 50, done.
# remote: Counting objects: 100% (50/50), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 50 (delta 10), reused 42 (delta 6), pack-reused 0 (from 0)
# Receiving objects: 100% (50/50), 8.44 MiB | 22.50 MiB/s, done.
# Resolving deltas: 100% (10/10), done.

# %%
# %%writefile README.md
#
# # TP Ciencias de Datos
#
# ## Descripción del Proyecto
# Este repositorio contiene el Trabajo Práctico de la materia Ciencias de Datos.
#
# ## Objetivos
# - Análisis exploratorio de datos
# - Limpieza y transformación de datos
# - Implementación de modelos predictivos
# - Visualización de resultados
#
# ## Estructura del Proyecto

# %%
### 3. **`CHANGELOG.md`** - Historial de cambios del proyecto

# %%writefile CHANGELOG.md

# Changelog

Todas las modificaciones importantes de este proyecto serán documentadas aquí.

## [1.0.0] - 2026-04-22

### Agregado
- Configuración inicial del repositorio
- Creación de archivo `.gitignore` para excluir archivos innecesarios
- Creación de `README.md` con documentación del proyecto
- Primer commit con notebook principal

### Próximos pasos
- [ ] Agregar análisis exploratorio de datos
- [ ] Implementar visualizaciones
- [ ] Crear modelo predictivo
- [ ] Agregar pruebas unitarias

## [0.1.0] - 2026-04-22

### Agregado
- Commit inicial con estructura base del proyecto

### Notas
- Este proyecto utiliza Google Colab para desarrollo
- Los datos no se suben al repositorio (ver .gitignore)

# %%
# %%writefile .gitignore

# %%
# !touch tpcd/data/raw/.gitkeep
# !touch tpcd/data/processed/.gitkeep
# !touch tpcd/data/interim/.gitkeep
# !touch tpcd/data/interim/plots/.gitkeep

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git add .

# !git commit -m "feat: Agregar nueva estructura de carpetas del proyecto"

# !git push origin master:main

# %% [markdown]
# ## B - Comprensión de los datos (Data Understanding - CRISP-DM)

# %% [markdown]
# # **INICIO PROYECTO**
# ##explorar

# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt

# %%
# !ls
# Out:
# sample_data  tpcd

# %%
df = pd.read_csv("/content/tpcd/tpcd/data/raw/Balaji Fast Food Sales.csv")

# %%
df = pd.read_csv("tpcd/data/raw/Balaji Fast Food Sales.csv")

# %%
df.head()
# Out:
#    order_id        date        item_name  item_type  item_price  quantity  \
# 0         1  07-03-2022         Aalopuri   Fastfood          20        13
# 1         2   8/23/2022          Vadapav   Fastfood          20        15
# 2         3  11/20/2022          Vadapav   Fastfood          20         1
# 3         4  02-03-2023  Sugarcane juice  Beverages          25         6
# 4         5  10-02-2022  Sugarcane juice  Beverages          25         8
#
#    transaction_amount transaction_type received_by time_of_sale
# 0                 260              NaN         Mr.        Night
# 1                 300             Cash         Mr.    Afternoon
# 2                  20             Cash         Mr.    Afternoon
# 3                 150           Online         Mr.        Night
# 4                 200           Online         Mr.      Evening

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            1000 non-null   int64
#  1   date                1000 non-null   object
#  2   item_name           1000 non-null   object
#  3   item_type           1000 non-null   object
#  4   item_price          1000 non-null   int64
#  5   quantity            1000 non-null   int64
#  6   transaction_amount  1000 non-null   int64
#  7   transaction_type    893 non-null    object
#  8   received_by         1000 non-null   object
#  9   time_of_sale        1000 non-null   object
# dtypes: int64(4), object(6)
# memory usage: 78.3+ KB

# %%
# Cantidad de datos nulos
df.isnull().sum()
# Out:
# order_id                0
# date                    0
# item_name               0
# item_type               0
# item_price              0
# quantity                0
# transaction_amount      0
# transaction_type      107
# received_by             0
# time_of_sale            0
# dtype: int64

# %%
df.describe()
# Out:
#           order_id   item_price     quantity  transaction_amount
# count  1000.000000  1000.000000  1000.000000         1000.000000
# mean    500.500000    33.315000     8.162000          275.230000
# std     288.819436    14.921744     4.413075          204.402979
# min       1.000000    20.000000     1.000000           20.000000
# 25%     250.750000    20.000000     4.000000          120.000000
# 50%     500.500000    25.000000     8.000000          240.000000
# 75%     750.250000    50.000000    12.000000          360.000000
# max    1000.000000    60.000000    15.000000          900.000000

# %%
# Ver columnas
df.columns
df.shape[1]
#Cantidad de filas
df.shape[0]
# Out:
# 1000

# %%
df['transaction_type']
# Out:
# 0         NaN
# 1        Cash
# 2        Cash
# 3      Online
# 4      Online
#         ...
# 995       NaN
# 996       NaN
# 997       NaN
# 998       NaN
# 999    Online
# Name: transaction_type, Length: 1000, dtype: object

# %%
df['date'].head()
# Out:
# 0    07-03-2022
# 1     8/23/2022
# 2    11/20/2022
# 3    02-03-2023
# 4    10-02-2022
# Name: date, dtype: object

# %%
# Análisis preliminar de calidad

# %%
# Unica columna con datos nulos "transaction_type"

porcentaje_nulos = (df["transaction_type"].isnull().sum() / len(df)) * 100

print("Porcentajes de datos nulos en la columna 'transaction_type'")
print(porcentaje_nulos)
# Out:
# Porcentajes de datos nulos en la columna 'transaction_type'
# 10.7

# %%
df["transaction_type"].unique()
# Out:
# array([nan, 'Cash', 'Online'], dtype=object)

# %% [markdown]
# #### Análisis a futuro:
# Detectamos que la unica columna con datos nulos es "transaction_type". Tenemos que determinar si normalizarla en base a otras variables y determinar si es "Cash" u "Online", o eliminar las filas que contengan ese dato nulo.
